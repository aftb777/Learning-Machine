# %%
i = 0 
while i < 5:
    print(i)
    i += 1
    
print()
print()

my_list = [1, 2, 3, 4, 5]
j = 0
while j < len(my_list):
    print(my_list[j])
    j += 1
    
print()
print()

while True:
    inp = input("Say Something: ")
    break
print("You said: " + inp)

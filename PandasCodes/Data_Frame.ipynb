# %%
import pandas as pd

car_data = pd.DataFrame({"Company" : ["Ford", "Chevy", "Toyota", "Honda"],
                         "Model" : ["F-150", "Camaro", "Corolla", "Civic"],
                         "MPG" : [20, 22, 30, 32]})

print(car_data)
# Out:
#   Company    Model  MPG
# 0    Ford    F-150   20
# 1   Chevy   Camaro   22
# 2  Toyota  Corolla   30
# 3   Honda    Civic   32

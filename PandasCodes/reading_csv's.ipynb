# %%
import pandas as pd

read = pd.read_csv("car-sales.csv")
print(read)

print()

print(read.Price) # csv file attribute

# Exporting the Data Frame
# read.to_csv("Exported-Car-Sales.csv", index=False)

print()


new = pd.read_csv("Exported-Car-Sales.csv")
print(new)

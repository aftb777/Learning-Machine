# %%
import pandas as pd

series = pd.Series(["BMW", "Toyota", "Honda"])
print(series)

print()

new_series = pd.Series(["BMW", "Toyota", "Honda"], index=["a", "b", "c"])
print(new_series)
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: str
#
# a       BMW
# b    Toyota
# c     Honda
# dtype: str

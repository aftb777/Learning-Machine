# %%
import numpy as np 

a1 = np.array([1, 2, 3, 9, 3, 7, 0])

print(np.sort(a1))
# Out:
# [0 1 2 3 3 7 9]

# %%
print(np.argsort(a1))
# Out:
# [6 0 1 2 4 5 3]

# %%
print(np.argsort(a1)[::-1])
# Out:
# [3 5 4 2 1 0 6]

# %%
print(np.argmax(a1))
print(np.argmin(a1))
# Out:
# 3
# 6

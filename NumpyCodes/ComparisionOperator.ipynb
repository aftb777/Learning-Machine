# %%
import numpy as np

a1 = np.array([1, 2, 3])
a2 = np.array([4, 5, 6])

print(a1 > a2)
# Out:
# [False False False]

# %%
print(a1 == a2)
# Out:
# [False False False]

# %%
print(a1 != a2)
# Out:
# [ True  True  True]

# %%
print(a1 < a2)
# Out:
# [ True  True  True]

# %%
print(a1 >= a2)
# Out:
# [False False False]

# %%
print(a1 <= a2)
# Out:
# [ True  True  True]

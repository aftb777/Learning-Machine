# %%
import numpy as np

a1 = np.array([1, 2, 3])
ones = np.ones(3)

# %timeit sum(a1)
# %timeit np.sum(a1)

print(np.mean(a1))

print()

print(np.var(a1))

print()

print(np.max(a1)) 

print(np.min(a1)) 


print()

print(np.median(a1))

print()

print(np.std(a1))
# Out:
# 556 ns ± 12.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 1.94 μs ± 116 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 2.0
#
# 0.6666666666666666
#
# 3
# 1
#
# 2.0
#
# 0.816496580927726

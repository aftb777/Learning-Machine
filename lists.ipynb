# %%
lists1 = [1, 2, 4, 'a', 'b', 'c', True, False, 1.2]

print(lists1)

print(lists1[0])  # 1
print(lists1[3])  # 'a'
print(lists1[-1])  # 1.2
print(lists1[-3])  # True

### Slicing
print(lists1[0:4:1]) # [start:stop:stepover]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()

# %% [markdown]
# Method 1

# %%
plt.plot([1, 3, 4, 6, 7, 9]);
plt.xlabel('data points')
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# Method 2

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
is_old = True
is_licensed = False

if is_old and not is_licensed:
    print("You need to renew your license.")
elif is_old and is_licensed:
    print("Your license is up to date.")
else:
    print("Your software is new.")
# Out:
# You need to renew your license.

# %%
my_list1 = [1, 2, 3, 4, 5]
your_list2 = [6, 7, 8, 9, 10]
their_list3 = [11, 12, 13, 14, 15]

print(list(zip(my_list1, your_list2, their_list3)))
# Out:
# [(1, 6, 11), (2, 7, 12), (3, 8, 13), (4, 9, 14), (5, 10, 15)]
